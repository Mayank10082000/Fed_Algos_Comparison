# %%
# Add the directory to Python path
import sys
sys.path.append('/kaggle/input/test101')

# Now run main.py
# !python /kaggle/input/test101/main.py
# Out:
# 2025-01-14 07:35:40.816323: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-14 07:35:40.989247: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-14 07:35:41.044649: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
#
# Loading and preprocessing data...
# Loading data...
# Preprocessing data...
# Figure(1200x600)
#
# Class Distribution (Before Undersampling):
# ----------------------------------------
# Class 2: 30,720 samples
# Class 3: 30,720 samples
# Class 4: 30,720 samples
# Class 5: 30,720 samples
# Class 6: 28,315 samples
# Class 7: 29,441 samples
# ...
